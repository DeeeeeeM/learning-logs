# %% [markdown]
# # Loops
# Demonstrates how to repeat actions using while and for loops.

# %%
# While loop example: repeat until a condition becomes false.
count = 0
print("Counting up with while:")
while count < 5:
    print(count)
    count += 1
# This loop will print numbers from 0 to 4, incrementing count by 1 each time.
# Out:
# Counting up with while:
# 0
# 1
# 2
# 3
# 4

# %%
# For loop example: iterate over a sequence of values.
print("Counting up with for:")
for number in range(5):
    print(number)
# This loop will also print numbers from 0 to 4, using the range function.
# Out:
# Counting up with for:
# 0
# 1
# 2
# 3
# 4

# %%
# range(start, stop, step) generates a sequence.
print("Even numbers from 0 to 8:")
for number in range(0, 10, 2):
    print(number)
# This loop will print even numbers from 0 to 8, starting at 0, stopping before 10, and stepping by 2.
# Out:
# Even numbers from 0 to 8:
# 0
# 2
# 4
# 6
# 8

# %%
# Loop over the characters in a string.
word = "Python"
print("Letters in the word:")
for letter in word:
    print(letter)
# This loop will print each letter in the word "Python" on a new line.
# Out:
# Letters in the word:
# P
# y
# t
# h
# o
# n

# %%
# Loop until user enters a valid answer.
answer = input("Type 'yes' when you are ready: ")
while answer.strip().lower() != "yes":
    answer = input("Please type 'yes' to continue: ")
print("Thank you! You are ready.")
# This while loop will keep asking the user to type 'yes' until they do, ignoring extra spaces and case.
# Out:
# Thank you! You are ready.

# %% [markdown]
# The object to the right of the "in" can be any object that supports iteration such as:

# %%
# lists
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
for planet in planets:
    print(planet, end=' ')
# Out:
# Mercury Venus Earth Mars Jupiter Saturn Uranus Neptune

# %%
# Tuples
multiplicands = (2, 2, 2, 3, 3, 5)
product = 1

for mult in multiplicands:
    product = product * mult
product

# Strings
s = 'steganograpHy is the practicE of conceaLing a file, message, image, or video within another fiLe, message, image, Or video.'
msg = ''
# print all the uppercase letters in s, one at a time
for char in s:
    if char.isupper():
        print(char, end='')      

# Dictionaries
for key in {"name": "Alice", "age": 25}:
    print(key)
    
# Sets
for item in {"apple", "banana", "orange"}:
    print(item)
    
# Ranges
for i in range(5):
    print("Doing important work. i =", i)

# Generators
for num in (x * 2 for x in range(3)):
    print(num)
    
# Files
#for line in open("data.txt"):
#    print(line)
# Out:
# HELLOname
# age
# apple
# banana
# orange
# Doing important work. i = 0
# Doing important work. i = 1
# Doing important work. i = 2
# Doing important work. i = 3
# Doing important work. i = 4
# 0
# 2
# 4

# %%
#List comprehensions
squares = [n**2 for n in range(10)]
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# with If condition 
short_planets = [planet for planet in planets if len(planet) < 6]
short_planets
# Out:
# ['Venus', 'Earth', 'Mars']

# %%
#Grasp the usual loop first then try to convert it to list comprehension
nums = [1, 2, 3, 4, 5]

result = []
for x in nums:
    result.append(x * 2)

print(result)
# Out:
# [2, 4, 6, 8, 10]

# %%
#Converted
result = [x * 2 for x in nums]
print (result)
# Out:
# [2, 4, 6, 8, 10]
